# %% [markdown]
# **Part 1: Understanding Convolutional Neural Networks (CNNs)**
#   specially designed to process visual data like images.
#   They can identify features such as edges, shapes, or objects
#
# **Key CNN Concepts Explained:**
# 1. Convolution Layer: Extracts features from input images using filters.
# 2. Pooling Layer: Reduces image size while retaining important features, making the network faster and less prone to overfitting.
# 4. Fully Connected Layer: Combines all detected features for classification.

# %%
#import the libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

#load and preprocess the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#reshape and normalize the data
X_train = X_train.reshape(-1, 28, 28, 1)/255.0
X_test = X_test.reshape(-1,28,28,1)/255.0

#one-hot encode labesl

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#step 2 Define the cnn model

cnn_model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])


#step 3 compile the model

cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#step 4 train the model

cnn_model.fit(X_train, y_train, epochs=5, validation_split=0.1, batch_size=32)

#step 5 Evaluate the model

test_loss, test_acc = cnn_model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_acc:.2f}')
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 45s 26ms/step - accuracy: 0.9060 - loss: 0.3130 - val_accuracy: 0.9815 - val_loss: 0.0653
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 81s 25ms/step - accuracy: 0.9832 - loss: 0.0550 - val_accuracy: 0.9840 - val_loss: 0.0553
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 42s 25ms/step - accuracy: 0.9899 - loss: 0.0338 - val_accuracy: 0.9885 - val_loss: 0.0465
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 82s 25ms/step - accuracy: 0.9938 - loss: 0.0206 - val_accuracy: 0.9840 - val_loss: 0.0606
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 42s 25ms/step - accuracy: 0.9956 - loss: 0.0141 - val_accuracy: 0.9857 - val_loss: 0.0545
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9838 - loss: 0.0533
# Test accuracy: 0.99

# %% [markdown]
# **Part 2: Understanding Recurrent Neural Networks (RNNs) ans LSTMs**
#
# **Key RNN/LSTM Concepts:**
# • **RNNs:** Pass information sequentially from one node to the next, learning patterns over time.
# • **LSTMs:** Use memory cells and gates to retain long-term dependencies, overcoming the limitations of traditional RNNs.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import numpy as np


#step 1 Generate sequential synthetic data
X_train = np.array([[[i+j]for i in range(5)] for j in range(100)])
y_train = np.array([i+5 for i in range(100)])

#rehspae the data for LSTM input
X_train = X_train.reshape((100,5,1))

# %%
#step 2 Define the LSTM model

lstm_model = Sequential([
    LSTM(50, activation='relu',input_shape=(5,1)),
    Dense(1)
])

#step 3 compile the model

lstm_model.compile(optimizer='adam', loss='mean_squared_error')


#step 4 train the model

lstm_model.fit(X_train, y_train, epochs=200, verbose=1)

#step 5 make predictions

test_data = np.array([[[i+5] for i in range(5)] for j in range(10)])
predictions = lstm_model.predict(test_data)

print(predictions)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3017.3875
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3092.5940
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2857.6243
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2751.0281
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2455.0122
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2332.5127
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2017.6066
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1451.8907
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 904.5450
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 338.8259
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.2710
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 76.4978
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.6828
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.6685
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5249
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.8874
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.6941
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2934
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5342
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5107
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6373
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4080
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3352
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7818
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2491
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9063
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5575
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5357
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5750
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3415
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2089
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9990
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0537
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9083
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8244
# Epoch 36/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8385
# Epoch 37/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8127
# Epoch 38/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6719
# Epoch 39/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7001
# Epoch 40/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6775
# Epoch 41/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7109
# Epoch 42/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6348
# Epoch 43/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6787
# Epoch 44/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5099
# Epoch 45/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4821
# Epoch 46/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5217
# Epoch 47/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5087
# Epoch 48/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3398
# Epoch 49/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4282
# Epoch 50/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3404
# Epoch 51/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3965
# Epoch 52/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2439
# Epoch 53/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3189
# Epoch 54/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2092
# Epoch 55/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1564
# Epoch 56/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2125
# Epoch 57/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1462
# Epoch 58/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2450
# Epoch 59/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1812
# Epoch 60/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1973
# Epoch 61/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1748
# Epoch 62/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1307
# Epoch 63/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1384
# Epoch 64/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1947
# Epoch 65/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1630
# Epoch 66/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1080
# Epoch 67/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1022
# Epoch 68/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1534
# Epoch 69/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1531
# Epoch 70/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1690
# Epoch 71/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0937
# Epoch 72/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0938
# Epoch 73/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1491
# Epoch 74/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0839
# Epoch 75/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0868
# Epoch 76/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0776
# Epoch 77/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1061
# Epoch 78/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0675
# Epoch 79/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0489
# Epoch 80/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1070
# Epoch 81/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0443
# Epoch 82/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0572
# Epoch 83/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0953
# Epoch 84/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0938
# Epoch 85/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0395
# Epoch 86/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0501
# Epoch 87/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0478
# Epoch 88/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0374
# Epoch 89/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0452
# Epoch 90/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0774
# Epoch 91/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0546
# Epoch 92/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0410
# Epoch 93/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0320
# Epoch 94/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0396
# Epoch 95/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0372
# Epoch 96/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0576
# Epoch 97/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0450
# Epoch 98/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0356
# Epoch 99/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0557
# Epoch 100/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0558
# Epoch 101/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0400
# Epoch 102/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0517
# Epoch 103/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0474
# Epoch 104/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0507
# Epoch 105/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0444
# Epoch 106/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0200
# Epoch 107/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0434
# Epoch 108/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0396
# Epoch 109/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0181
# Epoch 110/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0374
# Epoch 111/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0142
# Epoch 112/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0331
# Epoch 113/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0326
# Epoch 114/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 115/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0206
# Epoch 116/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0144
# Epoch 117/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0159
# Epoch 118/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0205
# Epoch 119/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183
# Epoch 120/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0142
# Epoch 121/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0121
# Epoch 122/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121
# Epoch 123/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0256
# Epoch 124/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0156
# Epoch 125/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0251
# Epoch 126/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0115
# Epoch 127/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0156
# Epoch 128/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0225
# Epoch 129/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0213
# Epoch 130/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135
# Epoch 131/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0088
# Epoch 132/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0137
# Epoch 133/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0098
# Epoch 134/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0086
# Epoch 135/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187
# Epoch 136/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0127
# Epoch 137/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0115
# Epoch 138/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 139/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112
# Epoch 140/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0168
# Epoch 141/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0164
# Epoch 142/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085
# Epoch 143/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0157
# Epoch 144/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0157
# Epoch 145/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094
# Epoch 146/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0092
# Epoch 147/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0103
# Epoch 148/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075
# Epoch 149/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100
# Epoch 150/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 151/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 152/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092
# Epoch 153/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090
# Epoch 154/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090
# Epoch 155/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085
# Epoch 156/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061
# Epoch 157/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0077
# Epoch 158/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063
# Epoch 159/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0089
# Epoch 160/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061
# Epoch 161/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081
# Epoch 162/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0054
# Epoch 163/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051
# Epoch 164/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Epoch 165/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045
# Epoch 166/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110
# Epoch 167/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Epoch 168/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100
# Epoch 169/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 170/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 171/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 172/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041
# Epoch 173/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0092
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0062
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0044
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0085
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0057
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0064
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0043
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0054
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0066
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# [[9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935311]
#  [9.935312]]
